# %% [markdown]
# ## First TensorFlow Code

# %%
import tensorflow as tf

# %%
a = tf.constant(2)
b = tf.constant(3)
x = tf.add(a, b)

# %%
with tf.Session() as sess:
    print(sess.run(x))
# Out:
# 5

# %% [markdown]
# ## Visualize it with TensorBoard

# %%
writer = tf.summary.FileWriter("./graphs", tf.get_default_graph())

# %%
with tf.Session() as sess:
    # writer = tf.summary.FileWriter("./graphs", sess.graph)
    print(sess.run(x))
# Out:
# 5

# %%
writer.close()

# %% [markdown]
# ## Explicitly name them

# %%
import tensorflow as tf

# %%
a = tf.constant(2, name="a")
b = tf.constant(3, name="b")
x = tf.add(a, b, name="add")

# %%
writer = tf.summary.FileWriter("./graphs", tf.get_default_graph())
with tf.Session() as sess:
    # writer = tf.summary.FileWriter("./graphs", sess.graph)
    print(sess.run(x))
writer.close()
# Out:
# 5

# %% [markdown]
# ## Constants

# %%
import tensorflow as tf

# %%
a = tf.constant([2, 2], name="a")
b = tf.constant([[0, 1], [2, 3]], name="b")

# %%
x = tf.multiply(a, b, name="mul")

# %%
with tf.Session() as sess:
    print(sess.run(x))
# Out:
# [[0 2]
#  [4 6]]

# %% [markdown]
# ## Tensors filled with a specific value

# %%
zeros = tf.zeros([2, 3], tf.int32)

# %%
with tf.Session() as sess:
    print(sess.run(zeros))
# Out:
# [[0 0 0]
#  [0 0 0]]

# %%
input_tensor = [[0, 1], [2, 3], [4, 5]]
zeros_like = tf.zeros_like(input_tensor)

# %%
with tf.Session() as sess:
    print(sess.run(zeros_like))
# Out:
# [[0 0]
#  [0 0]
#  [0 0]]

# %%
ones = tf.ones([2, 3], tf.int32)

# %%
with tf.Session() as sess:
    print(sess.run(ones))
# Out:
# [[1 1 1]
#  [1 1 1]]

# %%
input_tensor = [[0, 1], [2, 3], [4, 5]]
ones_like = tf.ones_like(input_tensor)

# %%
with tf.Session() as sess:
    print(sess.run(ones_like))
# Out:
# [[1 1]
#  [1 1]
#  [1 1]]

# %%
fill = tf.fill([2, 3], 8)
with tf.Session() as sess:
    print(sess.run(fill))
# Out:
# [[8 8 8]
#  [8 8 8]]

# %% [markdown]
# ## Constants as Sequences

# %%
lin_space = tf.lin_space(10.0, 13.0, 4)
with tf.Session() as sess:
    print(sess.run(lin_space))
# Out:
# [10. 11. 12. 13.]

# %%
tf_range = tf.range(3, 18, 3)
with tf.Session() as sess:
    print(sess.run(tf_range))
# Out:
# [ 3  6  9 12 15]

# %%
tf_range = tf.range(5)
with tf.Session() as sess:
    print(sess.run(tf_range))
# Out:
# [0 1 2 3 4]

# %% [markdown]
# #### NOT SAME AS Numpy Sequence

# %%
for _ in tf.range(5):
    print("*")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-7d3e251d3f0e> in <module>()
# ----> 1 for _ in tf.range(5):
#       2     print("*")
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __iter__(self)
#     394     if context.in_graph_mode():
#     395       raise TypeError(
# --> 396           "`Tensor` objects are not iterable when eager execution is not "
#     397           "enabled. To iterate over this tensor use `tf.map_fn`.")
#     398     shape = self._shape_tuple()
#
# TypeError: `Tensor` objects are not iterable when eager execution is not enabled. To iterate over this tensor use `tf.map_fn`.

# %% [markdown]
# ## Ramdomly Generated Constants

# %% [markdown]
# #### tf.random_normal
# #### tf.truncated_normal
# #### tf.random_uniform
# #### tf.random_shuffle
# #### tf.random_crop
# #### tf.multinomial
# #### tf.random_gamma

# %% [markdown]
# ## Operations

# %%
! (images/tf_operations.jpg)
# Out:
# /bin/sh: images/tf_operations.jpg: cannot execute binary file

# %%
from IPython.display import Image
Image("images/tf_operations.jpg")

# %% [markdown]
# ## Arithmetic Operations

# %% [markdown]
# #### tf.abs
# #### tf.negative
# #### tf.sign
# #### tf.reciprocal
# #### tf.square
# #### tf.round
# #### tf.sqrt
# #### tf.rsqrt
# #### tf.pow
# #### tf.exp

# %% [markdown]
# ## Wizard of Division

# %%
import tensorflow as tf

a = tf.constant([2, 2], name='a')
b = tf.constant([[0, 1], [2, 3]], name='b')
with tf.Session() as sess:
    print(sess.run(tf.div(b, a)))             # ⇒ [[0 0] [1 1]]
    print(sess.run(tf.divide(b, a)))          # ⇒ [[0. 0.5] [1. 1.5]]
    print(sess.run(tf.truediv(b, a)))         # ⇒ [[0. 0.5] [1. 1.5]]
    print(sess.run(tf.floordiv(b, a)))        # ⇒ [[0 0] [1 1]]
# Out:
# [[0 0]
#  [1 1]]
# [[0.  0.5]
#  [1.  1.5]]
# [[0.  0.5]
#  [1.  1.5]]
# [[0 0]
#  [1 1]]

# %%
with tf.Session() as sess:
    print(sess.run(tf.realdiv(b, a)))         # ⇒ # Error: only works for real values
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1349     try:
# -> 1350       return fn(*args)
#    1351     except errors.OpError as e:
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1319       # Ensure any changes to the graph are reflected in the runtime.
# -> 1320       self._extend_graph()
#    1321       with errors.raise_exception_on_not_ok_status() as status:
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _extend_graph(self)
#    1380           tf_session.TF_ExtendGraph(
# -> 1381               self._session, graph_def.SerializeToString(), status)
#    1382         self._opened = True
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# InvalidArgumentError: No OpKernel was registered to support Op 'RealDiv' with these attrs.  Registered devices: [CPU], Registered kernels:
#   device='CPU'; T in [DT_FLOAT]
#   device='CPU'; T in [DT_HALF]
#   device='CPU'; T in [DT_DOUBLE]
#   device='CPU'; T in [DT_COMPLEX64]
#   device='CPU'; T in [DT_COMPLEX128]
#
# 	 [[Node: RealDiv = RealDiv[T=DT_INT32](b, a)]]
#
# During handling of the above exception, another exception occurred:
#
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-2-d0432af56e4d> in <module>()
#       1 with tf.Session() as sess:
# ----> 2     print(sess.run(tf.realdiv(b, a)))         # ⇒ # Error: only works for real values
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1126     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1127       results = self._do_run(handle, final_targets, final_fetches,
# -> 1128                              feed_dict_tensor, options, run_metadata)
#    1129     else:
#    1130       results = []
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1342     if handle is None:
#    1343       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1344                            options, run_metadata)
#    1345     else:
#    1346       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1361         except KeyError:
#    1362           pass
# -> 1363       raise type(e)(node_def, op, message)
#    1364
#    1365   def _extend_graph(self):
#
# InvalidArgumentError: No OpKernel was registered to support Op 'RealDiv' with these attrs.  Registered devices: [CPU], Registered kernels:
#   device='CPU'; T in [DT_FLOAT]
#   device='CPU'; T in [DT_HALF]
#   device='CPU'; T in [DT_DOUBLE]
#   device='CPU'; T in [DT_COMPLEX64]
#   device='CPU'; T in [DT_COMPLEX128]
#
# 	 [[Node: RealDiv = RealDiv[T=DT_INT32](b, a)]]
#
# Caused by op 'RealDiv', defined at:
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-2-d0432af56e4d>", line 2, in <module>
#     print(sess.run(tf.realdiv(b, a)))         # ⇒ # Error: only works for real values
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py", line 3405, in _real_div
#     "RealDiv", x=x, y=y, name=name)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 3160, in create_op
#     op_def=op_def)
#   File "/Users/surkpark/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1625, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# InvalidArgumentError (see above for traceback): No OpKernel was registered to support Op 'RealDiv' with these attrs.  Registered devices: [CPU], Registered kernels:
#   device='CPU'; T in [DT_FLOAT]
#   device='CPU'; T in [DT_HALF]
#   device='CPU'; T in [DT_DOUBLE]
#   device='CPU'; T in [DT_COMPLEX64]
#   device='CPU'; T in [DT_COMPLEX128]
#
# 	 [[Node: RealDiv = RealDiv[T=DT_INT32](b, a)]]

# %%
with tf.Session() as sess:
    print(sess.run(tf.truncatediv(b, a)))     # ⇒ [[0 0] [1 1]]
    print(sess.run(tf.floor_div(b, a)))       # ⇒ [[0 0] [1 1]]
# Out:
# [[0 0]
#  [1 1]]
# [[0 0]
#  [1 1]]

# %% [markdown]
# ## TensorFlow Data Types

# %% [markdown]
# ### Python Native Types

# %%
import tensorflow as tf

# %%
t_0 = 19 # scalars are treated like 0-d tensors
tf.zeros_like(t_0) # ==> 0
tf.ones_like(t_0) # ==> 1

with tf.Session() as sess:
    print(sess.run(tf.zeros_like(t_0))) # ==> 0
    print(sess.run(tf.ones_like(t_0))) # ==> 1
# Out:
# 0
# 1

# %%
t_1 = [b"apple", b"peach", b"grape"] # 1-d arrays are treated like 1-d tensors
tf.zeros_like(t_1)                   # ==> [b'' b'' b'']
tf.ones_like(t_1)                    # ==> ?????

with tf.Session() as sess:
    print(sess.run(tf.zeros_like(t_1))) # ==> 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in ones(shape, dtype, name)
#    1630         raise TypeError(
# -> 1631             "preserving semantics from before tensors were iterable")
#    1632       shape = tensor_shape.as_shape(shape)
#
# TypeError: preserving semantics from before tensors were iterable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-77cfd2f2c6e1> in <module>()
#       1 t_1 = [b"apple", b"peach", b"grape"] # 1-d arrays are treated like 1-d tensors
#       2 tf.zeros_like(t_1)                   # ==> [b'' b'' b'']
# ----> 3 tf.ones_like(t_1)                    # ==> ?????
#       4
#       5 with tf.Session() as sess:
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in ones_like(tensor, dtype, name, optimize)
#    1596     if dtype is None:
#    1597       dtype = tensor.dtype
# -> 1598     ret = ones(ones_shape, dtype=dtype, name=name)
#    1599     if context.in_graph_mode():
#    1600       ret.set_shape(tensor.get_shape())
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in ones(shape, dtype, name)
#    1634     except (TypeError, ValueError):
#    1635       shape = ops.convert_to_tensor(shape, dtype=dtypes.int32, name="shape")
# -> 1636       output = fill(shape, constant(one, dtype=dtype), name=name)
#    1637   assert output.dtype.base_dtype == dtype
#    1638   return output
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name, verify_shape)
#     210   tensor_value.tensor.CopyFrom(
#     211       tensor_util.make_tensor_proto(
# --> 212           value, dtype=dtype, shape=shape, verify_shape=verify_shape))
#     213   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     214   const_tensor = g.create_op(
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape)
#     411       nparray = np.empty(shape, dtype=np_dt)
#     412     else:
# --> 413       _AssertCompatible(values, dtype)
#     414       nparray = np.array(values, dtype=np_dt)
#     415       # check to them.
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/tensor_util.py in _AssertCompatible(values, dtype)
#     326     else:
#     327       raise TypeError("Expected %s, got %s of type '%s' instead." %
# --> 328                       (dtype.name, repr(mismatch), type(mismatch).__name__))
#     329
#     330
#
# TypeError: Expected string, got 1 of type 'int' instead.

# %%
with tf.Session() as sess:
    print(sess.run(tf.ones_like(t_1))) # ==> 0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in ones(shape, dtype, name)
#    1630         raise TypeError(
# -> 1631             "preserving semantics from before tensors were iterable")
#    1632       shape = tensor_shape.as_shape(shape)
#
# TypeError: preserving semantics from before tensors were iterable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-08c5176e891e> in <module>()
#       1 with tf.Session() as sess:
# ----> 2     print(sess.run(tf.ones_like(t_1))) # ==> 0
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in ones_like(tensor, dtype, name, optimize)
#    1596     if dtype is None:
#    1597       dtype = tensor.dtype
# -> 1598     ret = ones(ones_shape, dtype=dtype, name=name)
#    1599     if context.in_graph_mode():
#    1600       ret.set_shape(tensor.get_shape())
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in ones(shape, dtype, name)
#    1634     except (TypeError, ValueError):
#    1635       shape = ops.convert_to_tensor(shape, dtype=dtypes.int32, name="shape")
# -> 1636       output = fill(shape, constant(one, dtype=dtype), name=name)
#    1637   assert output.dtype.base_dtype == dtype
#    1638   return output
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name, verify_shape)
#     210   tensor_value.tensor.CopyFrom(
#     211       tensor_util.make_tensor_proto(
# --> 212           value, dtype=dtype, shape=shape, verify_shape=verify_shape))
#     213   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     214   const_tensor = g.create_op(
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/tensor_util.py in make_tensor_proto(values, dtype, shape, verify_shape)
#     411       nparray = np.empty(shape, dtype=np_dt)
#     412     else:
# --> 413       _AssertCompatible(values, dtype)
#     414       nparray = np.array(values, dtype=np_dt)
#     415       # check to them.
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/tensorflow/python/framework/tensor_util.py in _AssertCompatible(values, dtype)
#     326     else:
#     327       raise TypeError("Expected %s, got %s of type '%s' instead." %
# --> 328                       (dtype.name, repr(mismatch), type(mismatch).__name__))
#     329
#     330
#
# TypeError: Expected string, got 1 of type 'int' instead.

# %%
t_2 = [[True, False, False],
  [False, False, True],
  [False, True, False]]         # 2-d arrays are treated like 2-d tensors

tf.zeros_like(t_2)                   # ==> 3x3 tensor, all elements are False
tf.ones_like(t_2)                    # ==> 3x3 tensor, all elements are True
# Out:
# <tf.Tensor 'ones_like_4:0' shape=(3, 3) dtype=bool>

# %%
with tf.Session() as sess:
    print(sess.run(tf.zeros_like(t_2)))
# Out:
# [[False False False]
#  [False False False]
#  [False False False]]

# %%
with tf.Session() as sess:
    print(sess.run(tf.ones_like(t_2)))
# Out:
# [[ True  True  True]
#  [ True  True  True]
#  [ True  True  True]]

# %% [markdown]
# ### TensorFlow Native Types

# %%
from IPython.display import Image
Image("images/tf_dtype.jpg")

# %% [markdown]
# ## TF vs. NP Data Types

# %%
import numpy as np

# %%
# TensorFlow integrates seamlessly with NumPy
tf.int32 == np.int32 # ⇒ True
# Out:
# True

# %%
#Can pass numpy types to TensorFlow ops
tf.ones([2, 2], np.float32) # ⇒ [[1.0 1.0], [1.0 1.0]]
# Out:
# <tf.Tensor 'ones:0' shape=(2, 2) dtype=float32>

# %%
#For  tf.Session.run(fetches): if the requested fetch is a Tensor , output will be a NumPy ndarray.
sess = tf.Session()
a = tf.zeros([2, 3], np.int32)
print(type(a))  # ⇒ <class 'tensorflow.python.framework.ops.Tensor'>
a = sess.run(a)
print(type(a))  # ⇒ <class 'numpy.ndarray'>
